# %%
# %load_ext autoreload
# %autoreload 2

import ratio
import count
import ratio_with_alpha
import count_with_alpha

# %% [markdown]
# ## Ratio with/without alpha
#
# True value for beta: 0.3
#
# True value for gamma: 0.05
#
# True value for S00: 0.9999

# %%
"""
Ratio with/without alpha
"""
beta0 = 0.000000000000000000000001
gamma0 = 0.03
S00 = 0.88

ratio.run_print(beta0, gamma0, S00, plot=True)
ratio_with_alpha.run_print(beta0, gamma0, S00, plot=True)

"""
Conclusion: When gamma0 and S00 are close from the real value, but beta is far away from the real value
Both perform good
ratio without alpha converges faster but with a higher cost in the end
ratio with alpha converges slower but more accurate
"""

# %%
"""
Ratio with/without alpha
"""
beta0 = 0.1
gamma0 = 0.000000001
S00 = 0.88

ratio.run_print(beta0, gamma0, S00, plot=True)
ratio_with_alpha.run_print(beta0, gamma0, S00, plot=True)

# %%
"""
Ratio with/without alpha
"""
beta0 = 0.1
gamma0 = 0.03
S00 = 0.03

ratio.run_print(beta0, gamma0, S00, plot=True)
ratio_with_alpha.run_print(beta0, gamma0, S00, plot=True)

# %% [markdown]
# ## Count with/without alpha, with division by N

# %%
"""
count
"""
from count import *

beta0 = 0.0000001
gamma0 = 0.00000003
S00 = 10

I_data = I + np.random.normal(0, 0.01 * I, size=I.shape)

count.run_print(I_data, beta0, gamma0, S00, plot=True)
count_with_alpha.run_print(I_data, beta0, gamma0, S00, plot=True)

# %%
from count_no_division_N_with_alpha import *

beta0 = 0.00001
gamma0 = 0.01
S00 = 100

I_data = I + np.random.normal(0, 0.01 * I, size=I.shape)

run_print(I_data, beta0, gamma0, S00, plot=True)
# Out:
# ...
# EXPERIMENT REPORT: WITH ALPHA TRICK
# ...
# --- CONVERGENCE ---
# Iterations: 20
# Final Cost: 245.47423245225852
# --------------------
# --- BETA ---
# True:      3e-05
# Initial:   1e-05
# Estimated: 2.9906183144743184e-05
# Error (%): 0.3127228508560556
# --------------------
# --- GAMMA ---
# True:      0.05
# Initial:   0.01
# Estimated: 0.04985596325849821
# Error (%): 0.2880734830035814
# --------------------
# --- S0 ---
# True:      9999
# Initial:   100
# Estimated: 9983.332382681738
# Error (%): 0.15669184236685943
# ...
